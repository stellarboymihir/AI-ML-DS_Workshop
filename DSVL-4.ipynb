# %% [markdown]
# # Use Netflix Movies and TV Shows dataset from Kaggle and perform following operation:
# # 1. Make a visualization showing the total number of movies watched by children
# # 2. Make a visualization showing the total number of standup comedies
# # 3. Make a visualization showing most watched shows.
# # 4. Make a visualization showing highest rate

# %%
# Dataset: netflix_titles.csv
# Location: https://drive.google.com/drive/folders/1YujA_GjKigwSJXbRJTkO1l2p1gMmm8ai

# %% [markdown]
# ## IMport the necessary libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('netflix_titles.csv')

# %%
df.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description',
#        'Unnamed: 12'],
#       dtype='object')

# %% [markdown]
# ###  Make a visualization showing the total number of movies watched by children

# %%
df['listed_in'].str.contains('Child')
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 7782    False
# 7783    False
# 7784    False
# 7785    False
# 7786    False
# Name: listed_in, Length: 7787, dtype: bool

# %%
sum(df['listed_in'].str.contains('Child'))
# Out:
# 532

# %%
df[df['listed_in'].str.contains('Child')]
# Out:
#      show_id   type                                    title  \
# 113     s114  Movie                      48 Christmas Wishes
# 145     s146  Movie                             A 2nd Chance
# 147     s148  Movie  A Babysitter's Guide to Monster Hunting
# 155     s156  Movie                         A Champion Heart
# 159     s160  Movie                       A Christmas Prince
# ...      ...    ...                                      ...
# 7745   s7746  Movie                     Yours, Mine and Ours
# 7761   s7762  Movie                                   Zapped
# 7772   s7773  Movie        Zipi & Zape y la Isla del Capitan
# 7776   s7777  Movie                                 Zokkomon
# 7781   s7782  Movie                                     Zoom
#
#                             director  \
# 113   Marco Deufemia, Justin G. Dyck
# 145                        Clay Glen
# 147                   Rachel Talalay
# 155                     David de Vos
# 159                        Alex Zamm
# ...

# %%
sns.countplot(x=df['listed_in'].str.contains('Child'))
# Out:
# <Axes: xlabel='listed_in', ylabel='count'>

# %%
child = sum(df['listed_in'].str.contains('Kid'))

# %% [markdown]
# ### Make a visualization showing the total number of standup comedies

# %%
df.head()
# Out:
#   show_id     type  title           director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie   7:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 cast        country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#           date_added  release_year rating   duration  \
# 0    August 14, 2020          2020  TV-MA  4 Seasons
# 1  December 23, 2016          2016  TV-MA     93 min
# 2  December 20, 2018          2011      R     78 min
# 3  November 16, 2017          2009  PG-13     80 min
# ...

# %%
df[df['listed_in'].str.contains('Stand')]
# Out:
#      show_id     type                                        title  \
# 197     s198  TV Show             A Little Help with Carol Burnett
# 220     s221    Movie                   A Russell Peters Christmas
# 284     s285  TV Show                              Abnormal Summit
# 305     s306    Movie          Adam Devine: Best Time of Our Lives
# 307     s308    Movie                      ADAM SANDLER 100% FRESH
# ...      ...      ...                                          ...
# 7718   s7719    Movie               Yoo Byung Jae: Discomfort Zone
# 7719   s7720    Movie          Yoo Byung Jae: Too Much Information
# 7744   s7745    Movie                  Yours Sincerely, Kanan Gill
# 7757   s7758    Movie  Zach Galifianakis: Live at the Purple Onion
# 7779   s7780  TV Show                                    Zona Rosa
#
#                      director  \
# 197                       NaN
# 220        Henry Sarwer-Foner
# 284   Jung-ah Im, Seung-uk Jo
# 305                 Jay Karas
# ...

# %%
suc = df[df['listed_in'].str.contains('Stand')]

# %%
suc
# Out:
#      show_id     type                                        title  \
# 197     s198  TV Show             A Little Help with Carol Burnett
# 220     s221    Movie                   A Russell Peters Christmas
# 284     s285  TV Show                              Abnormal Summit
# 305     s306    Movie          Adam Devine: Best Time of Our Lives
# 307     s308    Movie                      ADAM SANDLER 100% FRESH
# ...      ...      ...                                          ...
# 7718   s7719    Movie               Yoo Byung Jae: Discomfort Zone
# 7719   s7720    Movie          Yoo Byung Jae: Too Much Information
# 7744   s7745    Movie                  Yours Sincerely, Kanan Gill
# 7757   s7758    Movie  Zach Galifianakis: Live at the Purple Onion
# 7779   s7780  TV Show                                    Zona Rosa
#
#                      director  \
# 197                       NaN
# 220        Henry Sarwer-Foner
# 284   Jung-ah Im, Seung-uk Jo
# 305                 Jay Karas
# ...

# %%
suc.shape
# Out:
# (381, 13)

# %%
plt.bar(['Child Shows', 'Stand Up Comedy'],[child, len(suc)])
# Out:
# <BarContainer object of 2 artists>

# %%
plt.pie([child, len(suc)],
        labels = ['Child Shows', 'Stand-Up Comedy'],
        autopct = '%2.2f%%', shadow = True, radius = 1);

# %% [markdown]
# ### Make a visualization showing most watched shows.

# %%
df.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description',
#        'Unnamed: 12'],
#       dtype='object')

# %%
df.duration
# Out:
# 0       4 Seasons
# 1          93 min
# 2          78 min
# 3          80 min
# 4         123 min
#           ...
# 7782       99 min
# 7783      111 min
# 7784       44 min
# 7785     1 Season
# 7786       90 min
# Name: duration, Length: 7787, dtype: object

# %%
seasons = df[df.duration.str.contains('Season')]

# %%
seasons.sort_values(by =  'duration', ascending = False)
# Out:
#      show_id     type                         title            director  \
# 4404   s4405  TV Show                        Naruto         Hayato Date
# 2237   s2238  TV Show                Forensic Files                 NaN
# 468     s469  TV Show         American Horror Story                 NaN
# 5818   s5819  TV Show                    Still Game                 NaN
# 1181   s1182  TV Show              Call the Midwife  Philippa Lowthorpe
# ...      ...      ...                           ...                 ...
# 4225   s4226  TV Show                   More to Say                 NaN
# 4220   s4221  TV Show       Monzón: A Knockout Blow                 NaN
# 4219   s4220  TV Show  Monty Python's Personal Best                 NaN
# 1519   s1520  TV Show                      Crashing                 NaN
# 7785   s7786  TV Show         Zumbo's Just Desserts                 NaN
#
#                                                    cast  \
# ...

# %%
set(seasons.duration)
# Out:
# {'1 Season',
#  '10 Seasons',
#  '11 Seasons',
#  '12 Seasons',
#  '13 Seasons',
#  '15 Seasons',
#  '16 Seasons',
#  '2 Seasons',
#  '3 Seasons',
#  '4 Seasons',
#  '5 Seasons',
#  '6 Seasons',
#  '7 Seasons',
#  '8 Seasons',
#  '9 Seasons'}

# %%
seasons = seasons[seasons.duration.str.startswith('1')]

# %%
seasons
# Out:
#      show_id     type                  title              director  \
# 5         s6  TV Show                     46           Serdar Akar
# 11       s12  TV Show                   1983                   NaN
# 12       s13  TV Show                   1994  Diego Enrique Osorno
# 16       s17  TV Show                 Feb-09                   NaN
# 26       s27  TV Show               (Un)Well                   NaN
# ...      ...      ...                    ...                   ...
# 7766   s7767  TV Show           Zig & Sharko                   NaN
# 7767   s7768  TV Show     Zindagi Gulzar Hai                   NaN
# 7775   s7776  TV Show             Zoids Wild                   NaN
# 7779   s7780  TV Show              Zona Rosa                   NaN
# 7785   s7786  TV Show  Zumbo's Just Desserts                   NaN
#
#                                                    cast  \
# 5     Erdal Beşikçioğlu, Yasemin Allen, Melis Birkan...
# ...

# %%
seasons = seasons[seasons.duration.str.startswith('1')]

# %%
len(seasons[seasons.duration.str.startswith('1 ')])
# Out:
# 1608

# %%
ten = seasons[seasons.duration.str.startswith('10')]
eleven = seasons[seasons.duration.str.startswith('11')]
twelve = seasons[seasons.duration.str.startswith('12')]
thirteen = seasons[seasons.duration.str.startswith('13')]
fourteen = seasons[seasons.duration.str.startswith('14')]
fifteen = seasons[seasons.duration.str.startswith('15')]
sixteen = seasons[seasons.duration.str.startswith('16')]

# %%
plt.bar([10,11,12,13,15,16],
       [len(ten),len(eleven),len(twelve),len(thirteen),
        len(fifteen),len(sixteen)]
       )
# Out:
# <BarContainer object of 6 artists>

# %%
sns.countplot(x = seasons.duration);

# %% [markdown]
# ### Make a visualization showing most watched shows.

# %%
df.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description',
#        'Unnamed: 12'],
#       dtype='object')

# %%
sns.countplot(y = df.rating)
# Out:
# <Axes: xlabel='count', ylabel='rating'>

# %%
# Make a dashboard (DASHBOARD A) containing all of these above visualizations

# %%
plt.figure(figsize = (16,9))
plt.subplot(2,2,1)
sns.countplot(x=df['listed_in'].str.contains('Child'));
plt.subplot(2,2,2)
plt.pie([child, len(suc)],
        labels = ['Child Shows', 'Stand-Up Comedy'],
        autopct = '%2.2f%%', shadow = True, radius = 1.2);
plt.subplot(2,2,3)
plt.bar([10,11,12,13,15,16],
       [len(ten),len(eleven),len(twelve),len(thirteen),
        len(fifteen),len(sixteen)])
plt.subplot(2,2,4)
sns.countplot(y = df.rating)
plt.savefig('myplot.png')
