# %%
#Access an open source dataset 'TITANIC'.
#Apply preprocessing techniques on the raw
#dataset

# %%
import seaborn as sns

# %%
sns.get_dataset_names()#dataset names in seaborn
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
df = sns.load_dataset('titanic')

# %%
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df.duplicated()#duplicated entry
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 886     True
# 887    False
# 888    False
# 889    False
# 890    False
# Length: 891, dtype: bool

# %%
df.duplicated().sum()
# Out:
# 107

# %%
df.drop_duplicates(keep='first',inplace=True)#modify and restore - inplace

# %%
df.shape
# Out:
# (784, 15)

# %%
df.duplicated().sum()
# Out:
# Failed to start the Kernel.
#
# The Jupyter notebook server failed to launch in time.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
df_t = df.T#transposedf[]

# %%
df_t.shape
# Out:
# (15, 784)

# %%
df_t.duplicated()
# Out:
# survived       False
# pclass         False
# sex            False
# age            False
# sibsp          False
# parch          False
# fare           False
# embarked       False
# class          False
# who            False
# adult_male     False
# deck           False
# embark_town    False
# alive          False
# alone          False
# dtype: bool

# %%
df['sex'].value_counts()
# Out:
# male      491
# female    293
# Name: sex, dtype: int64

# %%
df['who'].value_counts()
# Out:
# man      451
# woman    251
# child     82
# Name: who, dtype: int64

# %%
df['survived'].value_counts()
# Out:
# 0    461
# 1    323
# Name: survived, dtype: int64

# %%
df['alive'].value_counts()
# Out:
# no     461
# yes    323
# Name: alive, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder#label encoding - str to numdf

# %%
le = LabelEncoder()

# %%
df['alive']=le.fit_transform(df['alive'])

# %%
df['alive']
# Out:
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 885    0
# 887    1
# 888    0
# 889    1
# 890    0
# Name: alive, Length: 784, dtype: int64

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town  alive  alone
# 0    man        True  NaN  Southampton      0  False
# 1  woman       False    C    Cherbourg      1  False
# 2  woman       False  NaN  Southampton      1   True
# 3  woman       False    C  Southampton      1  False
# 4    man        True  NaN  Southampton      0   True

# %%
df.count()
# Out:
# survived       784
# pclass         784
# sex            784
# age            678
# sibsp          784
# parch          784
# fare           784
# embarked       782
# class          784
# who            784
# adult_male     784
# deck           202
# embark_town    782
# alive          784
# alone          784
# dtype: int64

# %%
df.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            106
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           582
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
df.dropna()
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 1           1       1  female  38.0      1      0  71.2833        C  First
# 3           1       1  female  35.0      1      0  53.1000        S  First
# 6           0       1    male  54.0      0      0  51.8625        S  First
# 10          1       3  female   4.0      1      1  16.7000        S  Third
# 11          1       1  female  58.0      0      0  26.5500        S  First
# ..        ...     ...     ...   ...    ...    ...      ...      ...    ...
# 871         1       1  female  47.0      1      1  52.5542        S  First
# 872         0       1    male  33.0      0      0   5.0000        S  First
# 879         1       1  female  56.0      0      1  83.1583        C  First
# 887         1       1  female  19.0      0      0  30.0000        S  First
# 889         1       1    male  26.0      0      0  30.0000        C  First
#
#        who  adult_male deck  embark_town  alive  alone
# ...

# %%
df['age'].fillna(df['age'].mean())
# Out:
# 0      22.000000
# 1      38.000000
# 2      26.000000
# 3      35.000000
# 4      35.000000
#          ...
# 885    39.000000
# 887    19.000000
# 888    29.869351
# 889    26.000000
# 890    32.000000
# Name: age, Length: 784, dtype: float64

# %%
df['deck'].mode()[0]
# Out:
# 'C'

# %%
df.fillna(method='pad')
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0           0       3    male  22.0      1      0   7.2500        S  Third
# 1           1       1  female  38.0      1      0  71.2833        C  First
# 2           1       3  female  26.0      0      0   7.9250        S  Third
# 3           1       1  female  35.0      1      0  53.1000        S  First
# 4           0       3    male  35.0      0      0   8.0500        S  Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...    ...
# 885         0       3  female  39.0      0      5  29.1250        Q  Third
# 887         1       1  female  19.0      0      0  30.0000        S  First
# 888         0       3  female  19.0      1      2  23.4500        S  Third
# 889         1       1    male  26.0      0      0  30.0000        C  First
# 890         0       3    male  32.0      0      0   7.7500        Q  Third
#
#        who  adult_male deck  embark_town  alive  alone
# ...

# %%
df.fillna(method='backfill')
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0           0       3    male  22.0      1      0   7.2500        S  Third
# 1           1       1  female  38.0      1      0  71.2833        C  First
# 2           1       3  female  26.0      0      0   7.9250        S  Third
# 3           1       1  female  35.0      1      0  53.1000        S  First
# 4           0       3    male  35.0      0      0   8.0500        S  Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...    ...
# 885         0       3  female  39.0      0      5  29.1250        Q  Third
# 887         1       1  female  19.0      0      0  30.0000        S  First
# 888         0       3  female  26.0      1      2  23.4500        S  Third
# 889         1       1    male  26.0      0      0  30.0000        C  First
# 890         0       3    male  32.0      0      0   7.7500        Q  Third
#
#        who  adult_male deck  embark_town  alive  alone
# ...

# %%
import matplotlib.pyplot as plt

# %%
plt.boxplot(df['fare'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7ff7da9bec80>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7ff7da9bf1c0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7ff7da9be9e0>],
#  'medians': [<matplotlib.lines.Line2D at 0x7ff7da9bf700>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7ff7da9bf9a0>],
#  'means': []}
