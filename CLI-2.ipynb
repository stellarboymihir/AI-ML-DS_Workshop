# %% [markdown]
# ## Plot the Normal Distribution for class test result
# ## Particular subject & Identify the Skewness and Kurtosis

# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df = pd.read_csv('student.csv')

# %%
df['marks']
# Out:
# 0    56.77
# 1    59.77
# 2    76.88
# 3    69.66
# 4    63.28
# 5    49.55
# 6    65.34
# 7    68.33
# 8    56.75
# 9    78.66
# Name: marks, dtype: float64

# %%
sns.kdeplot(df['marks'])
# Out:
# <Axes: xlabel='marks', ylabel='Density'>

# %%
marks = [56,61,82,65,62,60,58,65,61]
sns.kdeplot(marks)
# Out:
# <Axes: ylabel='Density'>

# %%
marks = [86,85,65,76,89,75,54,75,85,89,90]
sns.kdeplot(marks)
# Out:
# <Axes: ylabel='Density'>

# %%
marks = [65,64,67,66,63,68,67,65,90,45]
sns.kdeplot(marks)
# Out:
# <Axes: ylabel='Density'>

# %% [markdown]
# Day-1
